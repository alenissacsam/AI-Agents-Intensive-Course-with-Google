# %% [markdown]
# # DAY 1a

# %%
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
root_agent = Agent(
    name="helpful_assistant",
    model="gemini-2.5-flash-lite",
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %%
response = await runner.run_debug("What is Agent Development Kit from Google? What languages is the SDK available in?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What is Agent Development Kit from Google? What languages is the SDK available in?
# helpful_assistant > The Agent Development Kit (ADK) from Google is a flexible, modular, and open-source framework designed to simplify the development and deployment of AI agents. It aims to make building AI agents feel more like traditional software development, providing developers with greater control and flexibility. ADK supports the creation of complex agentic architectures, from simple tasks to intricate workflows, and is particularly useful for developing multi-agent systems.
#
# The SDK is currently available in the following programming languages:
# *   **Python**
# *   **Java**
# *   **Go**

# %% [markdown]
# # Day 1b

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings", # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model="gemini-2.5-flash-lite",
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model="gemini-2.5-flash-lite",
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[
        AgentTool(research_agent),
        AgentTool(summarizer_agent)
    ],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("What are the latest advancements in quantum computing and what do they mean for AI?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline", # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model="gemini-2.5-flash-lite",
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft", # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model="gemini-2.5-flash-lite",
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog", # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the benefits of multi-agent systems for software developers")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > Here is a blog outline about the benefits of multi-agent systems for software developers:
#
# ## Headline: Unleash Your Development Superpowers: How Multi-Agent Systems Are Revolutionizing Software
#
# ### Introduction Hook:
#
# Imagine building software where individual components can communicate, collaborate, and even learn from each other, tackling complex problems more efficiently than ever before. This isn't science fiction; it's the power of multi-agent systems (MAS), and it's a game-changer for software developers.
#
# ### Main Sections:
#
# **1. Enhanced Problem-Solving Capabilities**
#
# *   **Decomposition of Complexity:** Break down large, intricate problems into smaller, manageable sub-problems, each handled by an independent agent.
# *   **Distributed Intelligence:** Leverage the collective knowledge and processing power of multiple agents to solve problems that would be intractable for a single entity.
# *   **Resilience and Robustness:** If one agent fails, the system can often continue to function, adapting to the loss and rerouting tasks.
#
# **2. Improved System Adaptability and Flexibility**
#
# *   **Dynamic Reconfiguration:** Agents can be added, removed, or modified during runtime, allowing systems to adapt to changing requirements or environments without full rewrites.
# *   **Autonomous Behavior:** Agents can act independently based on their own goals and perceptions, leading to more responsive and intelligent systems.
# *   **Emergent Behavior:** Complex and unexpected positive outcomes can arise from the interactions of simple agents, leading to innovative solutions.
#
# **3. Streamlined Development and Maintenance**
#
# *   **Modular Design:** MAS promotes a highly modular architecture, making code easier to understand, develop, and debug.
# *   **Parallel Development:** Different teams can work on individual agents concurrently, accelerating the development cycle.
# *   **Reusability:** Well-defined agents can be reused across different projects, saving development time and effort.
#
# ### Concluding Thought:
#
# Multi-agent systems offer a powerful paradigm shift for software development, empowering developers to build more intelligent, adaptable, and robust applications. By embracing MAS, you can unlock new levels of efficiency and innovation in your software projects.
# WriterAgent > ## Unleash Your Development Superpowers: How Multi-Agent Systems Are Revolutionizing Software
#
# Imagine building software where individual components can communicate, collaborate, and even learn from each other, tackling complex problems more efficiently than ever before. This isn't science fiction; it's the power of multi-agent systems (MAS), and it's a game-changer for software developers.
#
# MAS fundamentally enhances how we approach software development. Firstly, it excels at **enhanced problem-solving capabilities**. By breaking down intricate challenges into smaller, manageable tasks, each handled by an independent agent, we leverage **distributed intelligence**. This collective processing power tackles problems previously deemed intractable for a single entity. Crucially, MAS offers inherent **resilience and robustness**; if one agent falters, the system can often adapt, reroute tasks, and continue functioning.
#
# Beyond problem-solving, MAS dramatically improves **system adaptability and flexibility**. Its architecture supports **dynamic reconfiguration**, allowing agents to be added or modified during runtime, negating the need for full rewrites. This leads to more responsive and intelligent systems through **autonomous behavior**, where agents act independently based on their goals and perceptions. Moreover, the interactions between simple agents can lead to fascinating **emergent behavior**, fostering innovative and unexpected solutions.
#
# Finally, MAS promotes **streamlined development and maintenance**. The inherent **modular design** makes code easier to understand, develop, and debug. Different teams can work on individual agents concurrently, facilitating **parallel development** and accelerating project timelines. Furthermore, well-defined agents are highly **reusable** across various projects, significantly saving development time and effort.
#
# Multi-agent systems offer a powerful paradigm shift, empowering you to build more intelligent, adaptable, and robust applications. Embrace MAS to unlock new levels of efficiency and innovation in your software projects.
# EditorAgent > ## Unleash Your Development Superpowers: How Multi-Agent Systems Are Revolutionizing Software
#
# Imagine building software where individual components can communicate, collaborate, and even learn from each other, tackling complex problems more efficiently than ever before. This isn't science fiction; it's the power of multi-agent systems (MAS), and it's a game-changer for software developers.
#
# MAS fundamentally enhances how we approach software development. Firstly, it excels at **enhanced problem-solving capabilities**. By breaking down intricate challenges into smaller, manageable tasks, each handled by an independent agent, we leverage **distributed intelligence**. This collective processing power allows us to tackle problems previously deemed intractable for a single entity. Crucially, MAS offers inherent **resilience and robustness**; if one agent falters, the system can often adapt, reroute tasks, and continue functioning without significant disruption.
#
# Beyond problem-solving, MAS dramatically improves **system adaptability and flexibility**. Its architecture supports **dynamic reconfiguration**, allowing agents to be added or modified during runtime. This negates the need for full rewrites when requirements change, leading to more responsive and intelligent systems. This is further amplified by **autonomous behavior**, where agents act independently based on their goals and perceptions. Moreover, the interactions between these simple agents can lead to fascinating **emergent behavior**, fostering innovative and unexpected solutions.
#
# Finally, MAS promotes **streamlined development and maintenance**. The inherent **modular design** makes code easier to understand, develop, and debug. Different teams can work on individual agents concurrently, facilitating **parallel development** and accelerating project timelines. Furthermore, well-defined agents are highly **reusable** across various projects, significantly saving development time and effort.
#
# Multi-agent systems offer a powerful paradigm shift, empowering you to build more intelligent, adaptable, and robust applications. Embrace MAS to unlock new levels of efficiency and innovation in your software projects.

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research", # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research", # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research", # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model="gemini-2.5-flash-lite",
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary", # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Run the daily executive briefing on Tech, Health, and Finance")
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# FinanceResearcher > Here's your executive briefing for November 10, 2025:
#
# **Tech:** Agentic AI and advanced AI orchestration are key trends, focusing on autonomous task execution and efficient GPU resource management. Market implications include significant productivity gains and infrastructure shifts. The future outlook points to AI deeply embedded in workflows, demanding new "context engineering" skills and robust orchestration strategies.
#
# **Health:** Investments in robust digital infrastructure, like ERP and EHR systems, are crucial for strategic growth. AI is a top investment priority, enhancing diagnostics, population health, and physician productivity. Market implications include increased M&A activity and a rise in value-based care models. The future sees AI driving precision medicine, predictive analytics, and personalized patient experiences, alongside a growing demand for specialized services like urgent and behavioral health.
#
# **Finance:** The sector is seeing a strong integration of AI for efficiency and risk management, alongside a maturation of crypto-asset regulation. Quantum computing is being explored for optimization and security. Market implications include consolidation in banking, a focus on data-backed decision-making, and evolving global financial landscapes. The future points to a convergence of blockchain, quantum analytics, and AI, alongside increasing regulatory scrutiny on private capital and evolving payment innovations.
# HealthResearcher > Here's a brief executive summary of recent breakthroughs:
#
# **Health:**
# *   **AI-Driven Drug Repurposing:** AI is identifying new uses for existing medications, accelerating development and reducing costs for various diseases. Practical application: Faster, cheaper treatments for conditions like HIV and schizophrenia. Timeline: Already in use, with ongoing clinical trials and approvals.
# *   **Advanced Diagnostics:** Innovations include at-home COVID/flu tests and AI-enhanced mammography for earlier and more accurate detection. Practical application: Improved patient management, especially for high-risk individuals. Timeline: Flu/COVID tests available now; AI in diagnostics is rapidly advancing.
#
# **Technology:**
# *   **Agentic AI:** AI systems capable of autonomously planning and executing complex tasks are emerging. Practical application: Virtual coworkers for business workflows, enhancing efficiency. Timeline: Currently a major focus of experimentation, moving towards practical applications.
# *   **Quantum Computing Progress:** Advancements in quantum hardware, software, and algorithms are being made. Practical application: Drug discovery, materials science, and cybersecurity are key areas. Timeline: Widespread adoption uncertain, but progress is accelerating, with significant venture investment.
#
# **Finance:**
# *   **Embedded Finance:** Financial services are being integrated directly into non-financial platforms. Practical application: Seamless lending, payments, and insurance within e-commerce or brand apps. Timeline: Projected to reach $138 billion by 2026, with strong current momentum.
# *   **Tokenization of Assets:** Real-world assets are being converted into digital tokens. Practical application: Enabling fractional ownership, new investment opportunities, and streamlined transactions. Timeline: Emerging trend, with global coordination and frameworks being developed.
# TechResearcher > **AI/ML Trends: November 2025 Executive Briefing**
#
# **Key Developments:**
#
# 1.  **Agentic AI and Context Engineering:** AI systems are increasingly capable of performing complex, multi-step tasks autonomously. This is facilitated by "context engineering," where AI models are fed carefully structured background information for reliable task execution. Major tech firms like Google and Microsoft are actively developing agentic capabilities.
# 2.  **On-Device AI and Real-time Multimodality:** AI models are becoming more efficient, enabling processing directly on devices for enhanced privacy and lower latency. Simultaneously, AI is moving towards real-time multimodal interactions (combining vision, audio, and text), making applications more dynamic and interactive.
# 3.  **AI Integration in Healthcare and Finance:** Healthcare is seeing significant AI adoption for efficiency, cost reduction, and clinical support, with a focus on practical applications like early disease detection and administrative task automation. In finance, AI is revolutionizing fraud detection, customer service, and operational efficiency, with banks increasingly integrating AI strategies.
#
# **Main Companies Involved:**
#
# *   **Tech:** Google, Microsoft, Apple, OpenAI, NVIDIA
# *   **Healthcare:** Mayo Clinic, UCLA Health, Cleveland Clinic, Oracle, Nuance
# *   **Finance:** Major banks globally, C3.ai, Lazard, Citizens Bank
#
# **Potential Impact:**
#
# These trends indicate a shift towards more capable, integrated, and practical AI applications across industries. Agentic AI promises to automate complex workflows, while on-device and multimodal AI will enhance user experiences. In healthcare, this means improved patient care and operational efficiency. In finance, it translates to increased security, personalized services, and streamlined operations. However, challenges remain regarding ethical deployment, data privacy, and demonstrating clear ROI.
# AggregatorAgent > ## Executive Summary: Convergence of AI Across Tech, Health, and Finance
#
# **November 2025 Briefing**
#
# Across technology, healthcare, and finance, a dominant theme emerges: the pervasive and transformative impact of Artificial Intelligence. **Agentic AI**, capable of autonomous, multi-step task execution, is rapidly advancing and poised to become a virtual coworker across industries, demanding new "context engineering" skills. This trend is complemented by the rise of **on-device and real-time multimodal AI**, enhancing user experience through privacy-focused, dynamic interactions.
#
# In **healthcare**, AI is not just a priority but a driver of strategic growth. It's revolutionizing **diagnostics** through AI-enhanced mammography and at-home testing, and accelerating **drug repurposing** for faster, cheaper treatments. Investments in digital infrastructure are critical for this AI-driven evolution, leading to precision medicine and personalized patient experiences.
#
# The **finance** sector is similarly integrating AI for enhanced efficiency, robust **risk management**, and improved customer service. Simultaneously, innovative trends like **embedded finance** and the **tokenization of assets** are reshaping how financial services are delivered and accessed. While **quantum computing** is being explored for optimization and security, the convergence of AI, blockchain, and quantum analytics points towards an evolving global financial landscape.
#
# **Key Takeaways:**
#
# *   **AI is the central innovation** driving progress across all three sectors.
# *   **Agentic AI** represents a significant leap in automation and efficiency.
# *   **Healthcare and finance** are experiencing direct, practical applications of AI for diagnostics, drug development, risk management, and service delivery.
# *   The future points towards an **interconnected ecosystem** where AI, quantum computing, and blockchain will play increasingly integrated roles, necessitating strategic adaptation and ethical considerations.

# %% [markdown]
# # Loop Workflows - The Refinement Cycle

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story", # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique", # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    
    output_key="current_story", # It overwrites the story with the new, refined version.
    tools=[FunctionTool(exit_loop)], # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2, # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a short story about a lighthouse keeper who discovers a mysterious, glowing map")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias adjusted his spectacles, the salty air stinging his eyes. For thirty years, the beam of his lighthouse had sliced through the darkness, a solitary sentinel against the churning sea. Tonight, however, was different. While cleaning out a dusty storage closet, his hand brushed against something stiff tucked beneath a loose floorboard. It was a map, rolled tight and brittle with age. As he unrolled it, a faint luminescence pulsed from the parchment. Strange symbols, unlike any he’d ever seen, glowed with an ethereal blue light. They traced out islands and currents, but not of any known ocean. A chill, unrelated to the sea spray, traced its way down his spine. The map seemed to hum with a silent promise of the unknown, a secret whispered from the depths.
# CriticAgent > This is a strong start that effectively sets a mysterious and intriguing mood. Here are a few suggestions for improvement:
#
# 1.  **Expand on Elias's Reaction and Internal State:** While the "chill" is a good start, delve deeper into Elias's thoughts and feelings. After thirty years of routine, how does this discovery truly impact him? Is it fear, excitement, a sense of destiny, or a blend? Showing more of his internal monologue will make his character more relatable and the discovery more impactful. For example, does he question his sanity? Does a dormant sense of adventure awaken?
#
# 2.  **Add a Tangible Element of the "Unknown":** The map depicts "islands and currents, but not of any known ocean." To make this more concrete and draw the reader further in, consider adding a small, specific detail that Elias can observe. Perhaps a symbol on the map corresponds to a strange, unidentifiable constellation he sometimes sees through his telescope, or a specific current on the map eerily mirrors a peculiar ripple he once witnessed in the sea itself, something he'd dismissed until now.
#
# 3.  **Foreshadow the Next Step:** The story ends with the promise of the unknown. While this is good for intrigue, hint at what Elias might *do* next. Does he instinctively feel compelled to follow the map? Does he try to research the symbols? Even a subtle hint, like him looking out at the sea with new eyes, or his hand tracing a specific path on the map, would give the reader a stronger sense of direction for the continuation of the story.
# RefinerAgent > Elias adjusted his spectacles, the salty air stinging his eyes. For thirty years, the beam of his lighthouse had sliced through the darkness, a solitary sentinel against the churning sea. Tonight, however, was different. While cleaning out a dusty storage closet, his hand brushed against something stiff tucked beneath a loose floorboard. It was a map, rolled tight and brittle with age. As he unrolled it, a faint luminescence pulsed from the parchment. Strange symbols, unlike any he’d ever seen, glowed with an ethereal blue light. They traced out islands and currents, but not of any known ocean.
#
# A chill, unrelated to the sea spray, traced its way down his spine. Thirty years of predictable tides and familiar stars had lulled Elias into a comfortable routine, a life measured by the sweeping arc of his light. Now, this impossible artifact hummed in his hands, a secret whispered from the depths. Was he losing his mind? Had the isolation finally taken its toll? A flicker of something long dormant, a spark of audacious youth, ignited within him. It wasn’t just fear; it was a potent brew of wonder and a terrifying, exhilarating sense of destiny.
#
# His gaze darted from the glowing symbols to the world outside his lighthouse window. One particular cluster of swirling lines on the map, representing a treacherous-looking current, snagged his attention. It mirrored, with uncanny precision, a peculiar, almost intelligent-looking ripple he’d observed just last week out at sea – a phenomenon he’d dismissed as an anomaly. And the brightest symbol, a jagged spiral at the map's center, bore a striking resemblance to a cluster of stars that occasionally appeared in his telescope's view, a constellation that defied any chart he owned.
#
# The map seemed to hum with a silent promise of the unknown. Elias’s fingers, calloused from years of tending the lamp, traced the glowing blue lines. His eyes, usually fixed on the horizon for passing ships, now devoured the ancient markings. The sea outside, once a familiar adversary, now seemed to hold a deeper, more profound mystery, a beckoning call. He looked from the map to the vast, dark ocean, a new light dawning in his eyes. The routine was broken. The map was a question, and Elias felt an undeniable, irresistible pull to find its answer.
# CriticAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
