# %% [markdown]
# # DAY 1a

# %%
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
root_agent = Agent(
    name="helpful_assistant",
    model="gemini-2.5-flash-lite",
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %%
response = await runner.run_debug("What is Agent Development Kit from Google? What languages is the SDK available in?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What is Agent Development Kit from Google? What languages is the SDK available in?
# helpful_assistant > The Agent Development Kit (ADK) from Google is a flexible and modular framework designed to simplify the development, deployment, and orchestration of AI agents and multi-agent systems. It aims to make agent development more akin to traditional software development, allowing for robust debugging, versioning, and deployment. ADK is designed to be model-agnostic and deployment-agnostic, meaning it can work with various AI models and deployment environments, though it is optimized for Gemini and the Google Cloud ecosystem.
#
# The ADK SDK is available in the following languages:
# *   **Python**
# *   **Go**
# *   **Java**

# %% [markdown]
# # Day 1b

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings", # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model="gemini-2.5-flash-lite",
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model="gemini-2.5-flash-lite",
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[
        AgentTool(research_agent),
        AgentTool(summarizer_agent)
    ],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("What are the latest advancements in quantum computing and what do they mean for AI?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > The latest advancements in quantum computing hold significant promise for the future of Artificial Intelligence (AI). Quantum computers can potentially revolutionize AI by:
#
# *   **Enhancing AI Training and Optimization:** Speeding up the training of AI models, especially deep learning networks, and improving optimization tasks through algorithms like QAOA and VQE.
# *   **Improving Data Processing:** Processing and classifying large datasets more efficiently, leading to more accurate AI predictions.
# *   **Overcoming Classical Limitations:** Tackling complex problems currently intractable for classical computers, such as in drug discovery and materials science.
# *   **Enabling More Sustainable AI:** Offering energy-efficient solutions for AI, potentially reducing the high energy consumption of training large AI models.
# *   **Driving Hardware and Algorithm Progress:** Continuous advancements in qubit stability, coherence times, error correction, and scalability are making quantum computers more powerful and reliable.
# *   **Facilitating Hybrid Approaches:** The near future will likely see hybrid systems that combine quantum and classical computing to maximize their respective strengths.
# *   **Accelerating Scientific Discovery:** Quantum computers are becoming powerful tools for scientific exploration, as demonstrated by their use in discovering new phases of matter.
#
# In essence, the fusion of quantum computing and AI, known as Quantum AI, is poised to bring about transformative changes across various industries, including healthcare, finance, manufacturing, and energy.

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline", # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model="gemini-2.5-flash-lite",
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft", # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model="gemini-2.5-flash-lite",
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog", # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the benefits of multi-agent systems for software developers")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > Okay, I am OutlineAgent. Here is a blog outline about the benefits of multi-agent systems for software developers:
#
# ## Headline: Unleash Your Development Superpowers: How Multi-Agent Systems Will Revolutionize Your Code
#
# **Introduction Hook:**
# Tired of monolithic codebases that are a nightmare to maintain? Feeling overwhelmed by the complexity of modern software challenges? What if there was a way to break down those daunting tasks into manageable, intelligent pieces that work together seamlessly? Enter the world of Multi-Agent Systems (MAS) – a paradigm shift that's poised to make your life as a software developer significantly easier and your applications far more robust.
#
# ---
#
# ### Section 1: Decomposing Complexity with Intelligent Collaboration
#
# *   **Breaking Down the Monolith:** Learn how MAS allows you to divide large, intricate problems into smaller, independent "agents," each responsible for a specific sub-task or domain. This leads to cleaner, more modular code that's easier to understand and debug.
# *   **Specialized Expertise within Your Code:** Imagine agents designed for specific functions – one for data processing, another for user interface management, and a third for external API interactions. This specialization boosts efficiency and allows for focused development on individual components.
# *   **Enhanced Maintainability and Scalability:** When individual agents are easier to manage, updating or scaling specific parts of your application becomes a breeze. You can update or replace one agent without disrupting the entire system, fostering agility.
#
# ---
#
# ### Section 2: Building Resilient and Adaptive Applications
#
# *   **Fault Tolerance Through Decentralization:** If one agent fails, the system doesn't necessarily collapse. Other agents can often compensate or continue their operations, leading to more resilient software that can withstand partial failures.
# *   **Dynamic Problem Solving and Adaptation:** MAS can be designed to adapt to changing environments or unexpected situations. Agents can sense, reason, and act autonomously, enabling your application to respond intelligently to real-time events.
# *   **Learning and Evolution of System Behavior:** Advanced MAS can incorporate learning mechanisms, allowing agents to improve their performance over time based on their experiences and interactions, leading to continuously optimized applications.
#
# ---
#
# ### Section 3: Streamlining Development Workflows and Team Collaboration
#
# *   **Parallel Development and Specialization:** Different development teams or individual developers can work on distinct agents simultaneously, accelerating the overall development cycle.
# *   **Simplified Testing and Debugging:** Isolating and testing individual agents is far more manageable than debugging a large, intertwined codebase. This allows for more focused and efficient testing procedures.
# *   **Abstraction and Reusability:** Agents can be designed as reusable components that can be deployed across different projects, saving development time and promoting best practices.
#
# ---
#
# **Concluding Thought:**
# The principles of Multi-Agent Systems offer a powerful framework for tackling the ever-increasing complexity of modern software. By embracing this paradigm, developers can unlock new levels of modularity, resilience, and adaptability in their applications, while also streamlining their own development processes. It's time to think beyond the single, monolithic program and step into a future where intelligent, collaborative agents build the software of tomorrow.
# WriterAgent > ## Unleash Your Development Superpowers: How Multi-Agent Systems Will Revolutionize Your Code
#
# Are you tired of wrestling with monolithic codebases that feel like digital quicksand? Do the ever-growing complexities of modern software leave you feeling overwhelmed? Imagine a world where you could break down daunting challenges into smaller, intelligent pieces that collaborate like a well-oiled machine. Welcome to the exciting realm of Multi-Agent Systems (MAS), a paradigm shift set to transform how we build software, making your development life easier and your applications more robust than ever before.
#
# MAS empowers you to decompose intricate problems into independent "agents," each a master of its specific sub-task. This intelligent collaboration fosters cleaner, more modular code that's a joy to understand and debug. Think of it: specialized agents for data processing, UI management, or external API calls, boosting efficiency and allowing for focused development. This granular approach also drastically enhances maintainability and scalability; update or replace a single agent without causing system-wide meltdowns.
#
# Beyond modularity, MAS builds inherently resilient and adaptive applications. If one agent stumbles, the system doesn't collapse – others can often compensate, leading to remarkable fault tolerance. These systems can dynamically solve problems, adapting to changing environments and real-time events with autonomous reasoning. The potential for continuous optimization is immense, as advanced MAS can learn and evolve their behavior over time.
#
# Furthermore, MAS streamlines your entire development workflow. Teams can work on distinct agents in parallel, accelerating project timelines. Testing and debugging become a breeze when isolated to individual agents. Plus, these agents can be designed as reusable components, saving precious development time across multiple projects. Embrace MAS and unlock a future of modular, resilient, and adaptable software development.
# EditorAgent > Okay, WriterAgent, here's the polished blog post based on your draft and the outline provided by OutlineAgent. I've focused on improving flow, clarity, and grammatical correctness while retaining the enthusiastic tone and key points.
#
# ---
#
# ## Unleash Your Development Superpowers: How Multi-Agent Systems Will Revolutionize Your Code
#
# Are you tired of wrestling with monolithic codebases that feel like digital quicksand? Do the ever-growing complexities of modern software leave you feeling overwhelmed? Imagine a world where you could break down daunting challenges into smaller, intelligent pieces that collaborate like a well-oiled machine. Welcome to the exciting realm of Multi-Agent Systems (MAS) – a paradigm shift set to transform how we build software, making your development life easier and your applications more robust than ever before.
#
# ### Decomposing Complexity with Intelligent Collaboration
#
# MAS empowers you to decompose intricate problems into independent "agents," each a master of its specific sub-task or domain. This intelligent collaboration fosters cleaner, more modular code that's a joy to understand and debug. Imagine specialized agents dedicated to distinct functions: one for complex data processing, another for seamless user interface management, and a third for efficient external API interactions. This specialization not only boosts efficiency but also allows for highly focused development on individual components. This granular approach drastically enhances maintainability and scalability; you can update or replace a single agent without causing system-wide meltdowns, fostering greater agility.
#
# ### Building Resilient and Adaptive Applications
#
# Beyond modularity, MAS allows for the creation of inherently resilient and adaptive applications. If one agent encounters an issue, the entire system doesn't necessarily collapse. Other agents can often compensate or continue their operations, leading to remarkable fault tolerance and software that can withstand partial failures. These systems are also capable of dynamic problem-solving and adapting to changing environments or unexpected situations. With agents designed to sense, reason, and act autonomously, your applications can respond intelligently to real-time events. The potential for continuous optimization is immense, as advanced MAS can incorporate learning mechanisms, allowing agents to improve their performance over time based on their experiences and interactions, leading to continuously evolving and optimized applications.
#
# ### Streamlining Development Workflows and Team Collaboration
#
# Furthermore, MAS streamlines your entire development workflow. Different development teams or individual developers can work on distinct agents simultaneously, accelerating project timelines significantly. Testing and debugging become far more manageable when isolated to individual agents, allowing for more focused and efficient procedures. Critically, these agents can be designed as reusable components, promoting best practices and saving precious development time across multiple projects.
#
# Embrace MAS and unlock a future of modular, resilient, and adaptable software development. It's time to think beyond the single, monolithic program and step into a future where intelligent, collaborative agents build the software of tomorrow.

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research", # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research", # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research", # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model="gemini-2.5-flash-lite",
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary", # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Run the daily executive briefing on Tech, Health, and Finance")
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > **Health:** 1. **AI for Medical Imaging:** AI algorithms are significantly improving the accuracy and speed of diagnosing conditions like cancer from scans, with potential for widespread adoption in the next 1-3 years. 2. **Next-Gen mRNA Vaccines:** Advancements in mRNA technology are paving the way for rapid development of vaccines for various diseases, including cancer, with ongoing research and trials suggesting broader applications within 3-5 years. 3. **Living Mitral Valve Transplants:** Pioneering "domino" surgeries using donor living valves offer a promising alternative for children with heart conditions, with potential for wider clinical application in the next 5-7 years.
# FinanceResearcher > Here's your executive briefing on current trends in Tech, Health, and Finance:
#
# **Fintech:** Key trends include the mainstream adoption of emerging payment technologies, the increasing use of AI and machine learning for fraud reduction, and the growth of stablecoin usage. Market implications are faster, more secure transactions, but also a rise in sophisticated fraud attempts. The future outlook is one of continued innovation and evolving regulatory oversight.
#
# **Health:** Dominant trends are the transformative role of AI in diagnostics and operations, the expansion of telehealth services, and the rise of personalized and preventive healthcare solutions. Market implications include improved accessibility and patient satisfaction, but also concerns about rising costs and data privacy. The future points to more efficient, data-driven, and patient-centric care models.
#
# **Tech:** Leading trends include the pervasive integration of AI across sectors, the growth of cloud and edge computing, and the increasing focus on climate innovation and sustainability technologies. Market implications involve accelerated business operations, new energy market disruptions, and heightened cybersecurity risks. The future will see a convergence of AI, advanced computing, and automation, reshaping industries and demanding proactive strategic adaptation.
# TechResearcher > **AI/ML Trends Report: Key Developments for 2025**
#
# **Key Developments:**
#
# 1.  **Agentic AI:** AI systems capable of autonomous action are becoming more sophisticated, moving beyond simple task completion to proactive decision-making and workflow automation. Companies like Google, Salesforce, and OpenAI are investing in these agents for applications across finance, healthcare, and logistics.
# 2.  **Generative AI Expansion:** Beyond content creation, generative AI is now being applied to complex scientific and industrial tasks, including drug discovery, material science, and enhanced creative workflows. Tools from Google (Muse, Imagen) and OpenAI (ChatGPT) are at the forefront.
# 3.  **Specialized and Smaller Models:** Instead of relying solely on massive "frontier" models, there's a growing trend towards developing smaller, domain-specific AI models that offer greater efficiency and performance in niche industries.
#
# **Main Companies Involved:**
#
# Major players include **Microsoft**, heavily investing in AI infrastructure and integrating technologies like ChatGPT; **Nvidia**, dominating AI hardware with its GPUs; and **Alphabet** (Google), with its Gemini platform emphasizing multimodal capabilities. **OpenAI**, **Anthropic**, **Amazon**, and **Meta** are also significant contributors.
#
# **Potential Impact:**
#
# These advancements promise significant gains in efficiency, automation, and innovation across various sectors. However, they also raise ethical considerations and necessitate robust AI governance and security measures. The trend towards specialized models and accessible AI development platforms (low-code/no-code) is democratizing AI adoption.
# AggregatorAgent > Here's a consolidated executive summary of the latest trends across Tech, Health, and Finance:
#
# **Executive Briefing: Intersecting Trends in Tech, Health, and Finance**
#
# The pervasive integration of Artificial Intelligence (AI) is the dominant force reshaping all three sectors. In **Tech**, AI is evolving with agentic systems for autonomous decision-making, expanding generative capabilities beyond content creation to scientific tasks, and a rise in specialized, efficient models. Major players like Microsoft, Nvidia, and Alphabet are driving these advancements, which promise efficiency gains but also necessitate robust governance and security.
#
# This AI revolution is profoundly impacting **Health**, where algorithms are enhancing medical imaging accuracy for faster diagnoses within 1-3 years. mRNA technology is rapidly advancing vaccine development for various diseases, including cancer, with broader applications expected in 3-5 years. Furthermore, pioneering advancements in living valve transplants offer new hope for pediatric cardiac conditions within 5-7 years. The overall implication is more efficient, data-driven, and patient-centric healthcare, though data privacy and cost concerns remain.
#
# In **Finance**, AI and machine learning are critical for fraud reduction and securing emerging payment technologies, leading to faster, more secure transactions. The growth of stablecoins is also notable. These innovations are met with evolving regulatory oversight and sophisticated fraud attempts.
#
# A key takeaway is the accelerating convergence of AI across these domains, driving innovation, efficiency, and automation while simultaneously presenting challenges in security, ethics, and cost that require proactive strategic adaptation.

# %% [markdown]
# # Loop Workflows - The Refinement Cycle

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story", # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique", # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    
    output_key="current_story", # It overwrites the story with the new, refined version.
    tools=[FunctionTool(exit_loop)], # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2, # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a short story about a lighthouse keeper who discovers a mysterious, glowing map")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias had tended the light for thirty years, the rhythmic sweep of the beam his only constant companion. One storm-tossed evening, while checking the foghorn, his lamp glinted off something wedged between the rocks below. It was a rolled-up parchment, damp but strangely preserved. Unfurling it, he gasped. Not ink, but luminous, shifting symbols traced a coastline he didn't recognize. Islands pulsed with a soft, internal light. A single, brilliant star marked a point far out at sea. He ran a calloused finger over the glowing lines. This was no chart of his known world. It whispered of adventure, of secrets hidden beneath the waves, a siren call to a man who thought his life was already set in stone.
# CriticAgent > The story presents an intriguing premise with a strong hook. However, to elevate it further, consider the following:
#
# 1.  **Deepen Elias's Internal Conflict:** While the story states Elias's life was "set in stone," showing this through a brief internal reflection or a small detail about his routine would make his sudden pull towards adventure more impactful. For example, a fleeting thought about a past regret or a longing for something more before finding the map.
# 2.  **Enhance the Mystery of the Map:** The description of the luminous, shifting symbols is good, but adding a sensory detail beyond sight would heighten the mystery. Does the parchment feel unusual to the touch? Does it emit a faint sound or a particular scent?
# 3.  **Suggest a Next Step or Question:** The story ends with Elias feeling the "siren call." To create a more satisfying narrative arc, hint at what Elias might do next. Does he pocket the map, resolve to study it, or feel an immediate urge to act? A slightly more forward-looking conclusion would leave the reader with a stronger sense of anticipation.
# RefinerAgent > Elias had tended the light for thirty years, the rhythmic sweep of the beam his only constant companion. His days were a quiet liturgy of polishing brass, trimming wicks, and watching the endless, indifferent sea. He’d long since buried any youthful dreams of adventure, content in the solitary predictability of his post. One storm-tossed evening, while checking the foghorn, the wind snatching at his oilskins, his lamp glinted off something wedged between the rocks below. It was a rolled-up parchment, damp but strangely preserved, feeling unnaturally smooth and cool beneath his calloused fingers, almost alive. Unfurling it, he gasped. Not ink, but luminous, shifting symbols traced a coastline he didn't recognize. Islands pulsed with a soft, internal light, and a faint, almost inaudible hum seemed to emanate from the parchment itself. A single, brilliant star marked a point far out at sea. He ran a finger over the glowing lines, the light tingling against his skin. This was no chart of his known world. It whispered of adventure, of secrets hidden beneath the waves, a siren call to a man who thought his life was already set in stone. Pocketing the map, the strange coolness seeping through his trousers, Elias looked out at the churning darkness, a new, fierce resolve kindling in his chest. The sea had kept its secrets well, but tonight, it had given him one. And tomorrow, he would begin to unravel it.
# CriticAgent > APPROVED
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
